# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.AndroidStudio3.3',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.eclipse',
#  '.emulator_console_auth_token',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.p2',
#  '.spyder-py3',
#  '.templateengine',
#  '.tooling',
#  '3D Objects',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Belgelerim',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'eclipse',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{83bae342-9616-11e9-a9e6-f0677edf4e8f}.TM.blf',
#  'NTUSER.DAT{83bae342-9616-11e9-a9e6-f0677edf4e8f}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{83bae342-9616-11e9-a9e6-f0677edf4e8f}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Roaming',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'source',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Videos']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mbtbr'

# %%
import numpy as np
import matplotlib.pyplot as plt 
im=plt.imread('a.png')
type(im)
im.shape
# Out:
# (225, 225, 3)

# %%
im[100,100,:] #100,100 konumundaki renk değerleri
# Out:
# array([0.2784314 , 0.41960785, 0.62352943], dtype=float32)

# %%
plt.imshow(im)
plt.show() #resmi yazdırıyor

# %%
m,n,p = im.shape #resmin konum ve boyut değerlerini sırasıyla m,n,p'ye atar.
m,n,p
# Out:
# (225, 225, 3)

# %%
#Resmi siyah beyaz yapmak için: her pixel'i RGB'nin ortalamasına eşitliyoruz.

new_im=np.zeros((m,n),dtype=float) 

for i in range (m):
    for j in range (n):
        s=(im[i,j,0]+im[i,j,1]+im[i,j,2])/3
        new_im[i,j]=s

plt.imshow(new_im,cmap='gray')
plt.show() 
plt.imsave('siyahbeyaz.png',new_im,cmap='gray')

# %%
#Resmi 90 derece sola döndürmek için:

new_im=np.zeros((n,m),dtype=float) 

for i in range (m):
    for j in range (n):
        s=(im[i,j,0]+im[i,j,1]+im[i,j,2])/3
        new_im[j,i]=s

plt.imshow(new_im,cmap='gray')
plt.show() 
plt.imsave('doksanderece.png',new_im,cmap='gray')
